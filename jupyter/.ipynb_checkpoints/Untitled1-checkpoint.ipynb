# %%
import requests
import json

from pprint import pprint
from datetime import datetime

# %%
def fucken_datetime(month):
    month = str(month)
    if len(month) < 2:
        return '0' + month 
    else:
        return str(month)
        

date = datetime.now()
site = f'https://bank.gov.ua/NBUStatService/v1/statdirectory/exchange?date={date.year}{fucken_datetime(date.month)}{date.day}&json' # 20210609
# site = "https://api.privatbank.ua/p24api/pubinfo?exchange&coursid=5"
url = requests.get(site)
htmltext = url.text
text = json.loads(htmltext)
pprint(text)
# print(htmltext)
# Out:
# [{'cc': 'AUD',
#   'exchangedate': '18.06.2021',
#   'r030': 36,
#   'rate': 20.5672,
#   'txt': 'Австралійський долар'},
#  {'cc': 'CAD',
#   'exchangedate': '18.06.2021',
#   'r030': 124,
#   'rate': 22.034,
#   'txt': 'Канадський долар'},
#  {'cc': 'CNY',
#   'exchangedate': '18.06.2021',
#   'r030': 156,
#   'rate': 4.2186,
#   'txt': 'Юань Женьміньбі'},
#  {'cc': 'HRK',
#   'exchangedate': '18.06.2021',
#   'r030': 191,
#   'rate': 4.3284,
#   'txt': 'Куна'},
#  {'cc': 'CZK',
#   'exchangedate': '18.06.2021',
#   'r030': 203,
#   'rate': 1.2711,
#   'txt': 'Чеська крона'},
#  {'cc': 'DKK',
#   'exchangedate': '18.06.2021',
#   'r030': 208,
#   'rate': 4.3624,
#   'txt': 'Данська крона'},
#  {'cc': 'HKD',
#   'exchangedate': '18.06.2021',
#   'r030': 344,
#   'rate': 3.4992,
#   'txt': 'Гонконгівський долар'},
#  {'cc': 'HUF',
#   'exchangedate': '18.06.2021',
#   'r030': 348,
#   'rate': 0.09151,
#   'txt': 'Форинт'},
#  {'cc': 'INR',
#   'exchangedate': '18.06.2021',
# ...

# %%
for i in text:
#     print(i['txt'])
    if i['cc'] == 'USD':
        print(i['txt'], i['rate'])
    if i['cc'] == 'EUR':
        print(i['txt'], i['rate'])
# Out:
# Долар США 27.1712
# Євро 32.4424

# %%
for i in text:
    if i['cc'] == 'EUR':
        print(i['txt'])
# Out:
# Євро

# %%
a = datetime.now()
print(a.day)

type(a)
# Out:
# 18
# datetime.datetime

# %%
d = 10
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-7c9920a7e54c> in <module>
# ----> 1 date.month = 10
#
# AttributeError: attribute 'month' of 'datetime.date' objects is not writable

# %%
site = f'https://bank.gov.ua/NBUStatService/v1/statdirectory/exchange?date={date.year}0{date.month}&json'

# %%
print(site)
# Out:
# https://bank.gov.ua/NBUStatService/v1/statdirectory/exchange?date=202106&json
